# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df_D2= pd.read_csv('scamsD2_formatted.csv')
df_D2.columns = ['Date', 'Scam', 'Value']
print(df_D2.head())
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.ylabel('Value')
plt.xlabel('Date')
sns.lineplot(df_D2['Date'], df_D2['Value'],hue=df_D2['Scam'])
# Out:
#      Date      Scam         Value
# 0  May-17  Phishing  9.000000e+16
# 1  Jun-17  Fake ICO  3.940000e+18
# 2  Jun-17  Phishing  1.000000e+18
# 3  Jul-17  Scamming  2.150000e+18
# 4  Jul-17  Fake ICO  1.000000e+18
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Value'>
